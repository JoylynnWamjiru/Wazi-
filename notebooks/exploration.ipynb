# %% [markdown]
# # Wazi — Exploration
#
# Scratch notebook for experiments and prototyping (PDF extraction, embeddings, retrieval, prompt design). Nothing implemented yet.

# %%
# Exploration goes here
